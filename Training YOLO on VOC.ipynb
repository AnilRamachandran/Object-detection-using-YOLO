# %%
# To train YOLO you will need all of the VOC data
import os.path
from os import path
if path.exists("/anil/object_detection/VOCdevkit") == False:
    # !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar  
    # !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
    # !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar 
    # !tar -xvf VOCtrainval_11-May-2012.tar
    # !tar -xvf VOCtrainval_06-Nov-2007.tar
    # !tar -xvf VOCtest_06-Nov-2007.tar

# %%
# need to generate the label files that Darknet uses
if path.exists("/anil/object_detection/voc_label.py") == False:
    # !wget https://pjreddie.com/media/files/voc_label.py
# !python voc_label.py

# %%
# Darknet needs one text file with all of the images you want to train on
# %cat 2007_train.txt 2007_val.txt 2012_*.txt > train.txt

# %%
# In Darknet directory, we have to change the cfg/voc.data config file to point to your data
# classes= 20
# train  = /anil/object_detection/train.txt
# valid  = /anil/object_detection/2007_test.txt
# names = data/voc.names
# backup = backup

# %%
# for training we use convolutional weights that are pre-trained on darknet53 model
if path.exists("/anil/object_detection/darknet53.conv.74") == False:
    # !wget https://pjreddie.com/media/files/darknet53.conv.74

# %%
# Now train the model
# %cd /anil/object_detection/darknet
#!./darknet detector train cfg/voc.data cfg/yolov3-voc.cfg darknet53.conv.74
# !./darknet detector train cfg/voc.data cfg/yolov3-voc.cfg yolov3.weights
# Out:
# /anil/object_detection/darknet
# yolov3-voc
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32  0.299 BFLOPs
#     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32  0.177 BFLOPs
#     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     4 res    1                 208 x 208 x  64   ->   208 x 208 x  64
#     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     8 res    5                 104 x 104 x 128   ->   104 x 104 x 128
#     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
# ...

# %%
# test the modal 
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/dog.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
# detected objects is saved in predictions.jpg file
# %cd /anil/object_detection/darknet
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('/anil/object_detection/darknet/predictions.jpg')
imgplot = plt.imshow(img)
plt.show()
